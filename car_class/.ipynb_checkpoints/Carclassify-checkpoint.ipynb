# %%
from keras.applications.inception_v3 import InceptionV3
from keras.applications import VGG16
from keras.preprocessing import image
from keras.models import Model
from keras.layers import Dense, GlobalAveragePooling2D
from keras import backend as K
from keras import optimizers
import scipy.io
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# seeting
num_of_class = 3
crop_size = 224

# %% [markdown]
# ## Loading data

# %%
from keras.preprocessing.image import load_img, img_to_array
from keras.utils import np_utils
from keras.applications.imagenet_utils import preprocess_input

def load_data(image_paths, labels, crop_size):
    """
    Given list of paths, load images as one numpy array of shape
        (num_images, crop_size, crop_size, channel)
    :return X: image array
    "return y: one hot encoded labels
    """
    X = np.zeros((len(image_paths), crop_size, crop_size, 3))
    for i,path in enumerate(image_paths):
        X[i, :] = img_to_array(load_img(path, target_size=(crop_size, crop_size)))
    y = np_utils.to_categorical(labels, num_of_class)
    return X, y

train_paths = []
val_paths = []
test_paths = []
train_labels = []
val_labels = []
test_labels = []

train_anno = scipy.io.loadmat('./devkit/cars_train_annos.mat')['annotations'][0]
for i in train_anno:
    #train_labels += [i2i[i[-2][0][0]-1]]
    train_labels += [i[-2][0][0]-1]
    train_paths += ['./cars_train/' + str(i[-1][0])]

val_labels = train_labels[6144:]
val_paths = train_paths[6144:]
train_labels = train_labels[:6144]
train_paths = train_paths[:6144]

# %%
#X_train, y_train = load_data(train_paths[:3000], train_labels[:3000], crop_size)
#X_val, y_val = load_data(val_paths, val_labels, crop_size)
X_test, y_test = load_data(val_paths, val_labels, crop_size)
#X_train = preprocess_input(X_train)
#X_val = preprocess_input(X_val)
X_test = preprocess_input(X_test)

# %%
def generate_arrays(batch_size, crop_size = 224):
    sample_number = 6144
    while True:
        for i in range(0,sample_number,batch_size):
            if i + batch_size > sample_number:
                X_train, y_train = load_data(train_paths[i:], train_labels[i:], crop_size)
                X_train = preprocess_input(X_train)
            else:
                X_train, y_train = load_data(train_paths[i:i+batch_size], train_labels[i:i+batch_size], crop_size)
                X_train = preprocess_input(X_train)
            yield X_train, y_train

# %% [markdown]
# ## Build Model

# %%
def get_model( output_dim ):
    # create the base pre-trained model
    base_model = InceptionV3(weights='imagenet', include_top=False)
    # add a global spatial average pooling layer
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    # let's add a fully-connected layer
    x = Dense(1024, activation='relu')(x)
    # and a logistic layer|
    predictions = Dense(output_dim, activation='softmax')(x)
    model = Model(input=base_model.input, output=predictions)
    for layer in base_model.layers:
        layer.trainable = False
    return model
def get_model2(output_dim):
    vgg_model = VGG16( weights='imagenet', include_top=True )
    vgg_out = vgg_model.layers[-2].output #Last FC layer's output 
    softmax_layer = Dense(output_dim=output_dim, activation='softmax')(vgg_out)
    #Create new transfer learning model
    tl_model = Model( input=vgg_model.input, output=softmax_layer )

    #Freeze all layers of VGG16 and Compile the model
    for layer in vgg_model.layers[:-2]:
        layer.trainable = False
    #Confirm the model is appropriate
    #tl_model.compile(optimizer='RMSprop', loss='categorical_crossentropy', metrics=['accuracy'])
    #tl_model.summary()
    return tl_model

# %%
model = get_model2(num_of_class)
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_4 (InputLayer)             (None, None, None, 3) 0
# ____________________________________________________________________________________________________
# convolution2d_283 (Convolution2D (None, None, None, 32 896         input_4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_283 (BatchNor (None, None, None, 32 128         convolution2d_283[0][0]
# ____________________________________________________________________________________________________
# convolution2d_284 (Convolution2D (None, None, None, 32 9248        batchnormalization_283[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_284 (BatchNor (None, None, None, 32 128         convolution2d_284[0][0]
# ____________________________________________________________________________________________________
# convolution2d_285 (Convolution2D (None, None, None, 64 18496       batchnormalization_284[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_285 (BatchNor (None, None, None, 64 256         convolution2d_285[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_10 (MaxPooling2D)   (None, None, None, 64 0           batchnormalization_285[0][0]
# ____________________________________________________________________________________________________
# convolution2d_286 (Convolution2D (None, None, None, 80 5200        maxpooling2d_10[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_286 (BatchNor (None, None, None, 80 320         convolution2d_286[0][0]
# ____________________________________________________________________________________________________
# convolution2d_287 (Convolution2D (None, None, None, 19 138432      batchnormalization_286[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_287 (BatchNor (None, None, None, 19 768         convolution2d_287[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_11 (MaxPooling2D)   (None, None, None, 19 0           batchnormalization_287[0][0]
# ____________________________________________________________________________________________________
# convolution2d_291 (Convolution2D (None, None, None, 64 12352       maxpooling2d_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_291 (BatchNor (None, None, None, 64 256         convolution2d_291[0][0]
# ____________________________________________________________________________________________________
# convolution2d_289 (Convolution2D (None, None, None, 48 9264        maxpooling2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_292 (Convolution2D (None, None, None, 96 55392       batchnormalization_291[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_289 (BatchNor (None, None, None, 48 192         convolution2d_289[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_292 (BatchNor (None, None, None, 96 384         convolution2d_292[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_31 (AveragePool (None, None, None, 19 0           maxpooling2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_288 (Convolution2D (None, None, None, 64 12352       maxpooling2d_11[0][0]
# ____________________________________________________________________________________________________
# convolution2d_290 (Convolution2D (None, None, None, 64 76864       batchnormalization_289[0][0]
# ____________________________________________________________________________________________________
# convolution2d_293 (Convolution2D (None, None, None, 96 83040       batchnormalization_292[0][0]
# ____________________________________________________________________________________________________
# convolution2d_294 (Convolution2D (None, None, None, 32 6176        averagepooling2d_31[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_288 (BatchNor (None, None, None, 64 256         convolution2d_288[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_290 (BatchNor (None, None, None, 64 256         convolution2d_290[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_293 (BatchNor (None, None, None, 96 384         convolution2d_293[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_294 (BatchNor (None, None, None, 32 128         convolution2d_294[0][0]
# ____________________________________________________________________________________________________
# mixed0 (Merge)                   (None, None, None, 25 0           batchnormalization_288[0][0]
#                                                                    batchnormalization_290[0][0]
#                                                                    batchnormalization_293[0][0]
#                                                                    batchnormalization_294[0][0]
# ____________________________________________________________________________________________________
# convolution2d_298 (Convolution2D (None, None, None, 64 16448       mixed0[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_298 (BatchNor (None, None, None, 64 256         convolution2d_298[0][0]
# ____________________________________________________________________________________________________
# convolution2d_296 (Convolution2D (None, None, None, 48 12336       mixed0[0][0]
# ____________________________________________________________________________________________________
# convolution2d_299 (Convolution2D (None, None, None, 96 55392       batchnormalization_298[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_296 (BatchNor (None, None, None, 48 192         convolution2d_296[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_299 (BatchNor (None, None, None, 96 384         convolution2d_299[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_32 (AveragePool (None, None, None, 25 0           mixed0[0][0]
# ____________________________________________________________________________________________________
# convolution2d_295 (Convolution2D (None, None, None, 64 16448       mixed0[0][0]
# ____________________________________________________________________________________________________
# convolution2d_297 (Convolution2D (None, None, None, 64 76864       batchnormalization_296[0][0]
# ____________________________________________________________________________________________________
# convolution2d_300 (Convolution2D (None, None, None, 96 83040       batchnormalization_299[0][0]
# ____________________________________________________________________________________________________
# convolution2d_301 (Convolution2D (None, None, None, 32 8224        averagepooling2d_32[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_295 (BatchNor (None, None, None, 64 256         convolution2d_295[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_297 (BatchNor (None, None, None, 64 256         convolution2d_297[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_300 (BatchNor (None, None, None, 96 384         convolution2d_300[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_301 (BatchNor (None, None, None, 32 128         convolution2d_301[0][0]
# ____________________________________________________________________________________________________
# mixed1 (Merge)                   (None, None, None, 25 0           batchnormalization_295[0][0]
#                                                                    batchnormalization_297[0][0]
#                                                                    batchnormalization_300[0][0]
#                                                                    batchnormalization_301[0][0]
# ____________________________________________________________________________________________________
# convolution2d_305 (Convolution2D (None, None, None, 64 16448       mixed1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_305 (BatchNor (None, None, None, 64 256         convolution2d_305[0][0]
# ____________________________________________________________________________________________________
# convolution2d_303 (Convolution2D (None, None, None, 48 12336       mixed1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_306 (Convolution2D (None, None, None, 96 55392       batchnormalization_305[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_303 (BatchNor (None, None, None, 48 192         convolution2d_303[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_306 (BatchNor (None, None, None, 96 384         convolution2d_306[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_33 (AveragePool (None, None, None, 25 0           mixed1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_302 (Convolution2D (None, None, None, 64 16448       mixed1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_304 (Convolution2D (None, None, None, 64 76864       batchnormalization_303[0][0]
# ____________________________________________________________________________________________________
# convolution2d_307 (Convolution2D (None, None, None, 96 83040       batchnormalization_306[0][0]
# ____________________________________________________________________________________________________
# convolution2d_308 (Convolution2D (None, None, None, 32 8224        averagepooling2d_33[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_302 (BatchNor (None, None, None, 64 256         convolution2d_302[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_304 (BatchNor (None, None, None, 64 256         convolution2d_304[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_307 (BatchNor (None, None, None, 96 384         convolution2d_307[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_308 (BatchNor (None, None, None, 32 128         convolution2d_308[0][0]
# ____________________________________________________________________________________________________
# mixed2 (Merge)                   (None, None, None, 25 0           batchnormalization_302[0][0]
#                                                                    batchnormalization_304[0][0]
#                                                                    batchnormalization_307[0][0]
#                                                                    batchnormalization_308[0][0]
# ____________________________________________________________________________________________________
# convolution2d_310 (Convolution2D (None, None, None, 64 16448       mixed2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_310 (BatchNor (None, None, None, 64 256         convolution2d_310[0][0]
# ____________________________________________________________________________________________________
# convolution2d_311 (Convolution2D (None, None, None, 96 55392       batchnormalization_310[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_311 (BatchNor (None, None, None, 96 384         convolution2d_311[0][0]
# ____________________________________________________________________________________________________
# convolution2d_309 (Convolution2D (None, None, None, 38 885120      mixed2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_312 (Convolution2D (None, None, None, 96 83040       batchnormalization_311[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_309 (BatchNor (None, None, None, 38 1536        convolution2d_309[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_312 (BatchNor (None, None, None, 96 384         convolution2d_312[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_12 (MaxPooling2D)   (None, None, None, 25 0           mixed2[0][0]
# ____________________________________________________________________________________________________
# mixed3 (Merge)                   (None, None, None, 73 0           batchnormalization_309[0][0]
#                                                                    batchnormalization_312[0][0]
#                                                                    maxpooling2d_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_317 (Convolution2D (None, None, None, 12 94336       mixed3[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_317 (BatchNor (None, None, None, 12 512         convolution2d_317[0][0]
# ____________________________________________________________________________________________________
# convolution2d_318 (Convolution2D (None, None, None, 12 114816      batchnormalization_317[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_318 (BatchNor (None, None, None, 12 512         convolution2d_318[0][0]
# ____________________________________________________________________________________________________
# convolution2d_314 (Convolution2D (None, None, None, 12 94336       mixed3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_319 (Convolution2D (None, None, None, 12 114816      batchnormalization_318[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_314 (BatchNor (None, None, None, 12 512         convolution2d_314[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_319 (BatchNor (None, None, None, 12 512         convolution2d_319[0][0]
# ____________________________________________________________________________________________________
# convolution2d_315 (Convolution2D (None, None, None, 12 114816      batchnormalization_314[0][0]
# ____________________________________________________________________________________________________
# convolution2d_320 (Convolution2D (None, None, None, 12 114816      batchnormalization_319[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_315 (BatchNor (None, None, None, 12 512         convolution2d_315[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_320 (BatchNor (None, None, None, 12 512         convolution2d_320[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_34 (AveragePool (None, None, None, 73 0           mixed3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_313 (Convolution2D (None, None, None, 19 141504      mixed3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_316 (Convolution2D (None, None, None, 19 172224      batchnormalization_315[0][0]
# ____________________________________________________________________________________________________
# convolution2d_321 (Convolution2D (None, None, None, 19 172224      batchnormalization_320[0][0]
# ____________________________________________________________________________________________________
# convolution2d_322 (Convolution2D (None, None, None, 19 141504      averagepooling2d_34[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_313 (BatchNor (None, None, None, 19 768         convolution2d_313[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_316 (BatchNor (None, None, None, 19 768         convolution2d_316[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_321 (BatchNor (None, None, None, 19 768         convolution2d_321[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_322 (BatchNor (None, None, None, 19 768         convolution2d_322[0][0]
# ____________________________________________________________________________________________________
# mixed4 (Merge)                   (None, None, None, 76 0           batchnormalization_313[0][0]
#                                                                    batchnormalization_316[0][0]
#                                                                    batchnormalization_321[0][0]
#                                                                    batchnormalization_322[0][0]
# ____________________________________________________________________________________________________
# convolution2d_327 (Convolution2D (None, None, None, 16 123040      mixed4[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_327 (BatchNor (None, None, None, 16 640         convolution2d_327[0][0]
# ____________________________________________________________________________________________________
# convolution2d_328 (Convolution2D (None, None, None, 16 179360      batchnormalization_327[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_328 (BatchNor (None, None, None, 16 640         convolution2d_328[0][0]
# ____________________________________________________________________________________________________
# convolution2d_324 (Convolution2D (None, None, None, 16 123040      mixed4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_329 (Convolution2D (None, None, None, 16 179360      batchnormalization_328[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_324 (BatchNor (None, None, None, 16 640         convolution2d_324[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_329 (BatchNor (None, None, None, 16 640         convolution2d_329[0][0]
# ____________________________________________________________________________________________________
# convolution2d_325 (Convolution2D (None, None, None, 16 179360      batchnormalization_324[0][0]
# ____________________________________________________________________________________________________
# convolution2d_330 (Convolution2D (None, None, None, 16 179360      batchnormalization_329[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_325 (BatchNor (None, None, None, 16 640         convolution2d_325[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_330 (BatchNor (None, None, None, 16 640         convolution2d_330[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_35 (AveragePool (None, None, None, 76 0           mixed4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_323 (Convolution2D (None, None, None, 19 147648      mixed4[0][0]
# ____________________________________________________________________________________________________
# convolution2d_326 (Convolution2D (None, None, None, 19 215232      batchnormalization_325[0][0]
# ____________________________________________________________________________________________________
# convolution2d_331 (Convolution2D (None, None, None, 19 215232      batchnormalization_330[0][0]
# ____________________________________________________________________________________________________
# convolution2d_332 (Convolution2D (None, None, None, 19 147648      averagepooling2d_35[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_323 (BatchNor (None, None, None, 19 768         convolution2d_323[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_326 (BatchNor (None, None, None, 19 768         convolution2d_326[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_331 (BatchNor (None, None, None, 19 768         convolution2d_331[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_332 (BatchNor (None, None, None, 19 768         convolution2d_332[0][0]
# ____________________________________________________________________________________________________
# mixed5 (Merge)                   (None, None, None, 76 0           batchnormalization_323[0][0]
#                                                                    batchnormalization_326[0][0]
#                                                                    batchnormalization_331[0][0]
#                                                                    batchnormalization_332[0][0]
# ____________________________________________________________________________________________________
# convolution2d_337 (Convolution2D (None, None, None, 16 123040      mixed5[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_337 (BatchNor (None, None, None, 16 640         convolution2d_337[0][0]
# ____________________________________________________________________________________________________
# convolution2d_338 (Convolution2D (None, None, None, 16 179360      batchnormalization_337[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_338 (BatchNor (None, None, None, 16 640         convolution2d_338[0][0]
# ____________________________________________________________________________________________________
# convolution2d_334 (Convolution2D (None, None, None, 16 123040      mixed5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_339 (Convolution2D (None, None, None, 16 179360      batchnormalization_338[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_334 (BatchNor (None, None, None, 16 640         convolution2d_334[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_339 (BatchNor (None, None, None, 16 640         convolution2d_339[0][0]
# ____________________________________________________________________________________________________
# convolution2d_335 (Convolution2D (None, None, None, 16 179360      batchnormalization_334[0][0]
# ____________________________________________________________________________________________________
# convolution2d_340 (Convolution2D (None, None, None, 16 179360      batchnormalization_339[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_335 (BatchNor (None, None, None, 16 640         convolution2d_335[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_340 (BatchNor (None, None, None, 16 640         convolution2d_340[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_36 (AveragePool (None, None, None, 76 0           mixed5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_333 (Convolution2D (None, None, None, 19 147648      mixed5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_336 (Convolution2D (None, None, None, 19 215232      batchnormalization_335[0][0]
# ____________________________________________________________________________________________________
# convolution2d_341 (Convolution2D (None, None, None, 19 215232      batchnormalization_340[0][0]
# ____________________________________________________________________________________________________
# convolution2d_342 (Convolution2D (None, None, None, 19 147648      averagepooling2d_36[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_333 (BatchNor (None, None, None, 19 768         convolution2d_333[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_336 (BatchNor (None, None, None, 19 768         convolution2d_336[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_341 (BatchNor (None, None, None, 19 768         convolution2d_341[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_342 (BatchNor (None, None, None, 19 768         convolution2d_342[0][0]
# ____________________________________________________________________________________________________
# mixed6 (Merge)                   (None, None, None, 76 0           batchnormalization_333[0][0]
#                                                                    batchnormalization_336[0][0]
#                                                                    batchnormalization_341[0][0]
#                                                                    batchnormalization_342[0][0]
# ____________________________________________________________________________________________________
# convolution2d_347 (Convolution2D (None, None, None, 16 123040      mixed6[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_347 (BatchNor (None, None, None, 16 640         convolution2d_347[0][0]
# ____________________________________________________________________________________________________
# convolution2d_348 (Convolution2D (None, None, None, 19 215232      batchnormalization_347[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_348 (BatchNor (None, None, None, 19 768         convolution2d_348[0][0]
# ____________________________________________________________________________________________________
# convolution2d_344 (Convolution2D (None, None, None, 19 147648      mixed6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_349 (Convolution2D (None, None, None, 19 258240      batchnormalization_348[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_344 (BatchNor (None, None, None, 19 768         convolution2d_344[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_349 (BatchNor (None, None, None, 19 768         convolution2d_349[0][0]
# ____________________________________________________________________________________________________
# convolution2d_345 (Convolution2D (None, None, None, 19 258240      batchnormalization_344[0][0]
# ____________________________________________________________________________________________________
# convolution2d_350 (Convolution2D (None, None, None, 19 258240      batchnormalization_349[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_345 (BatchNor (None, None, None, 19 768         convolution2d_345[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_350 (BatchNor (None, None, None, 19 768         convolution2d_350[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_37 (AveragePool (None, None, None, 76 0           mixed6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_343 (Convolution2D (None, None, None, 19 147648      mixed6[0][0]
# ____________________________________________________________________________________________________
# convolution2d_346 (Convolution2D (None, None, None, 19 258240      batchnormalization_345[0][0]
# ____________________________________________________________________________________________________
# convolution2d_351 (Convolution2D (None, None, None, 19 258240      batchnormalization_350[0][0]
# ____________________________________________________________________________________________________
# convolution2d_352 (Convolution2D (None, None, None, 19 147648      averagepooling2d_37[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_343 (BatchNor (None, None, None, 19 768         convolution2d_343[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_346 (BatchNor (None, None, None, 19 768         convolution2d_346[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_351 (BatchNor (None, None, None, 19 768         convolution2d_351[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_352 (BatchNor (None, None, None, 19 768         convolution2d_352[0][0]
# ____________________________________________________________________________________________________
# mixed7 (Merge)                   (None, None, None, 76 0           batchnormalization_343[0][0]
#                                                                    batchnormalization_346[0][0]
#                                                                    batchnormalization_351[0][0]
#                                                                    batchnormalization_352[0][0]
# ____________________________________________________________________________________________________
# convolution2d_355 (Convolution2D (None, None, None, 19 147648      mixed7[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_355 (BatchNor (None, None, None, 19 768         convolution2d_355[0][0]
# ____________________________________________________________________________________________________
# convolution2d_356 (Convolution2D (None, None, None, 19 258240      batchnormalization_355[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_356 (BatchNor (None, None, None, 19 768         convolution2d_356[0][0]
# ____________________________________________________________________________________________________
# convolution2d_353 (Convolution2D (None, None, None, 19 147648      mixed7[0][0]
# ____________________________________________________________________________________________________
# convolution2d_357 (Convolution2D (None, None, None, 19 258240      batchnormalization_356[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_353 (BatchNor (None, None, None, 19 768         convolution2d_353[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_357 (BatchNor (None, None, None, 19 768         convolution2d_357[0][0]
# ____________________________________________________________________________________________________
# convolution2d_354 (Convolution2D (None, None, None, 32 553280      batchnormalization_353[0][0]
# ____________________________________________________________________________________________________
# convolution2d_358 (Convolution2D (None, None, None, 19 331968      batchnormalization_357[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_354 (BatchNor (None, None, None, 32 1280        convolution2d_354[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_358 (BatchNor (None, None, None, 19 768         convolution2d_358[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_38 (AveragePool (None, None, None, 76 0           mixed7[0][0]
# ____________________________________________________________________________________________________
# mixed8 (Merge)                   (None, None, None, 12 0           batchnormalization_354[0][0]
#                                                                    batchnormalization_358[0][0]
#                                                                    averagepooling2d_38[0][0]
# ____________________________________________________________________________________________________
# convolution2d_363 (Convolution2D (None, None, None, 44 573888      mixed8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_363 (BatchNor (None, None, None, 44 1792        convolution2d_363[0][0]
# ____________________________________________________________________________________________________
# convolution2d_360 (Convolution2D (None, None, None, 38 491904      mixed8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_364 (Convolution2D (None, None, None, 38 1548672     batchnormalization_363[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_360 (BatchNor (None, None, None, 38 1536        convolution2d_360[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_364 (BatchNor (None, None, None, 38 1536        convolution2d_364[0][0]
# ____________________________________________________________________________________________________
# convolution2d_361 (Convolution2D (None, None, None, 38 442752      batchnormalization_360[0][0]
# ____________________________________________________________________________________________________
# convolution2d_362 (Convolution2D (None, None, None, 38 442752      batchnormalization_360[0][0]
# ____________________________________________________________________________________________________
# convolution2d_365 (Convolution2D (None, None, None, 38 442752      batchnormalization_364[0][0]
# ____________________________________________________________________________________________________
# convolution2d_366 (Convolution2D (None, None, None, 38 442752      batchnormalization_364[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_39 (AveragePool (None, None, None, 12 0           mixed8[0][0]
# ____________________________________________________________________________________________________
# convolution2d_359 (Convolution2D (None, None, None, 32 409920      mixed8[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_361 (BatchNor (None, None, None, 38 1536        convolution2d_361[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_362 (BatchNor (None, None, None, 38 1536        convolution2d_362[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_365 (BatchNor (None, None, None, 38 1536        convolution2d_365[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_366 (BatchNor (None, None, None, 38 1536        convolution2d_366[0][0]
# ____________________________________________________________________________________________________
# convolution2d_367 (Convolution2D (None, None, None, 19 245952      averagepooling2d_39[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_359 (BatchNor (None, None, None, 32 1280        convolution2d_359[0][0]
# ____________________________________________________________________________________________________
# mixed9_0 (Merge)                 (None, None, None, 76 0           batchnormalization_361[0][0]
#                                                                    batchnormalization_362[0][0]
# ____________________________________________________________________________________________________
# merge_7 (Merge)                  (None, None, None, 76 0           batchnormalization_365[0][0]
#                                                                    batchnormalization_366[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_367 (BatchNor (None, None, None, 19 768         convolution2d_367[0][0]
# ____________________________________________________________________________________________________
# mixed9 (Merge)                   (None, None, None, 20 0           batchnormalization_359[0][0]
#                                                                    mixed9_0[0][0]
#                                                                    merge_7[0][0]
#                                                                    batchnormalization_367[0][0]
# ____________________________________________________________________________________________________
# convolution2d_372 (Convolution2D (None, None, None, 44 917952      mixed9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_372 (BatchNor (None, None, None, 44 1792        convolution2d_372[0][0]
# ____________________________________________________________________________________________________
# convolution2d_369 (Convolution2D (None, None, None, 38 786816      mixed9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_373 (Convolution2D (None, None, None, 38 1548672     batchnormalization_372[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_369 (BatchNor (None, None, None, 38 1536        convolution2d_369[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_373 (BatchNor (None, None, None, 38 1536        convolution2d_373[0][0]
# ____________________________________________________________________________________________________
# convolution2d_370 (Convolution2D (None, None, None, 38 442752      batchnormalization_369[0][0]
# ____________________________________________________________________________________________________
# convolution2d_371 (Convolution2D (None, None, None, 38 442752      batchnormalization_369[0][0]
# ____________________________________________________________________________________________________
# convolution2d_374 (Convolution2D (None, None, None, 38 442752      batchnormalization_373[0][0]
# ____________________________________________________________________________________________________
# convolution2d_375 (Convolution2D (None, None, None, 38 442752      batchnormalization_373[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_40 (AveragePool (None, None, None, 20 0           mixed9[0][0]
# ____________________________________________________________________________________________________
# convolution2d_368 (Convolution2D (None, None, None, 32 655680      mixed9[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_370 (BatchNor (None, None, None, 38 1536        convolution2d_370[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_371 (BatchNor (None, None, None, 38 1536        convolution2d_371[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_374 (BatchNor (None, None, None, 38 1536        convolution2d_374[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_375 (BatchNor (None, None, None, 38 1536        convolution2d_375[0][0]
# ____________________________________________________________________________________________________
# convolution2d_376 (Convolution2D (None, None, None, 19 393408      averagepooling2d_40[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_368 (BatchNor (None, None, None, 32 1280        convolution2d_368[0][0]
# ____________________________________________________________________________________________________
# mixed9_1 (Merge)                 (None, None, None, 76 0           batchnormalization_370[0][0]
#                                                                    batchnormalization_371[0][0]
# ____________________________________________________________________________________________________
# merge_8 (Merge)                  (None, None, None, 76 0           batchnormalization_374[0][0]
#                                                                    batchnormalization_375[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_376 (BatchNor (None, None, None, 19 768         convolution2d_376[0][0]
# ____________________________________________________________________________________________________
# mixed10 (Merge)                  (None, None, None, 20 0           batchnormalization_368[0][0]
#                                                                    mixed9_1[0][0]
#                                                                    merge_8[0][0]
#                                                                    batchnormalization_376[0][0]
# ____________________________________________________________________________________________________
# globalaveragepooling2d_4 (Global (None, 2048)          0           mixed10[0][0]
# ____________________________________________________________________________________________________
# dense_7 (Dense)                  (None, 1024)          2098176     globalaveragepooling2d_4[0][0]
# ____________________________________________________________________________________________________
# dense_8 (Dense)                  (None, 196)           200900      dense_7[0][0]
# ====================================================================================================
# Total params: 23,911,044
# Trainable params: 2,299,076
# Non-trainable params: 21,611,968
# ____________________________________________________________________________________________________

# %%
#only model
from keras.models import load_model
model = load_model('./model/New folder/test.99-2.01.hdf5')

# %% [markdown]
# ## training

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='./model/test.{epoch:02d}-{val_loss:.2f}.hdf5', period = 5)

# %%
#model.compile(optimizer='rmsprop',
#              loss='categorical_crossentropy',
#              metrics=['accuracy'])
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],
              optimizer=optimizers.SGD(lr=0.0001 , momentum=0.9, nesterov=True))
model.fit_generator(generate_arrays(batch_size=64),
                    validation_data=(X_test, y_test),
                    samples_per_epoch=6144, nb_epoch=1000,
                   callbacks=[checkpointer])
# Out:
# Epoch 1/1000
# 3072/6144 [==============>...............] - ETA: 36s - loss: 5.5135 - acc: 0.0062

# %% [markdown]
# ## Predict

# %%
pred = model.predict(X_test)

# %%
pred[1].argmax()
# Out:
# 9

# %%
s = [1,2,3,4]
s[:-2]
# Out:
# [1, 2]

# %%
def original(img):
    tmp = np.zeros_like(img)
    for i in range(3):
        tmp[:,:,i] = img[:,:,i] - img[:,:,i].min()
    return tmp.astype(np.uint8)

# %%
for i in range(1000,1500):
    print (make[pred[i].argmax()], i2c[y_test[i].argmax()])
# Out:
# Dodge Jeep
# BMW BMW
# Volkswagen Volkswagen
# Ford Ford
# Chevrolet Scion
# GMC Chevrolet
# Dodge Rolls-Royce
# Chevrolet Chevrolet
# Dodge GMC
# BMW Bentley
# BMW BMW
# Dodge Ford
# Nissan Bentley
# Ford Ford
# Chevrolet Ford
# GMC Nissan
# Ford Chevrolet
# Ford Ford
# Aston Ferrari
# Land Land
# Volkswagen Chevrolet
# Chevrolet Chevrolet
# Chevrolet Chevrolet
# Chevrolet Bentley
# Hyundai Acura
# Dodge Dodge
# Lamborghini Acura
# Suzuki Suzuki
# Audi BMW
# Chevrolet Acura
# BMW Acura
# Hyundai Mercedes-Benz
# Dodge Volvo
# Ford Honda
# Hyundai Hyundai
# Chevrolet Mitsubishi
# Hyundai Hyundai
# Volkswagen Dodge
# Chevrolet GMC
# Toyota Toyota
# BMW Lamborghini
# Audi Chevrolet
# BMW BMW
# Honda Hyundai
# Cadillac Hyundai
# Mercedes-Benz Chrysler
# Chevrolet Acura
# Audi Chevrolet
# BMW BMW
# Chevrolet Chevrolet
# Audi Audi
# Nissan Cadillac
# Hyundai Ford
# Ferrari Ferrari
# Lamborghini Lamborghini
# Jeep Jeep
# Hyundai Hyundai
# Chevrolet smart
# Lamborghini Lamborghini
# Spyker Spyker
# Chevrolet Chevrolet
# BMW Audi
# Chevrolet Infiniti
# Hyundai Hyundai
# Chevrolet Dodge
# Chevrolet Ram
# Hyundai Hyundai
# Chevrolet Chevrolet
# Daewoo Audi
# Acura Acura
